# %%
import os
import time
import requests
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
product="Anouk kurtas"
#Define the path to chrome Webdriver executable

#Initialize the chrome Webdriver

driver = webdriver.Chrome()

#Navigate the URL
driver.get("https://www.myntra.com/kurtas?rawquery="+product)

#once the page is loaded, you can extract the page text
myntra_text = driver.page_source

myntra_html = bs(myntra_text, "html.parser")

# %%
myntra_text
# Out:
# '<html lang="en"><head><title>Kurtas - Buy Kurtas ( कुरता ) for Men and Women Online - Myntra</title><meta name="theme-color" content="#fffff"><link rel="dns-prefetch preconnect" href="https://constant.myntassets.com"><link rel="dns-prefetch preconnect" href="https://assets.myntassets.com"><link rel="dns-prefetch preconnect" href="https//www.googletagmanager.com"><link rel="dns-prefetch preconnect" href="https//www.google-analytics.com"><link rel="dns-prefetch preconnect" href="https//connect.facebook.net"><link rel="dns-prefetch preconnect" href="https://www.facebook.com"><link rel="dns-prefetch preconnect" href="https://touch.myntra.com"><link rel="manifest" href="/manifest.json"><link rel="search" type="application/opensearchdescription+xml" href="https://www.myntra.com/opensearch.xml" title="Myntra Fashion Search"><link rel="apple-touch-icon" href="https://constant.myntassets.com/pwa/assets/img/Icon-App-60x60@3x_2021.png">\n      <link rel="preload" as="script" href="https://cons
# ...

# %%
myntra_html
# Out:
# <html lang="en"><head><title>Kurtas - Buy Kurtas ( कुरता ) for Men and Women Online - Myntra</title><meta content="#fffff" name="theme-color"/><link href="https://constant.myntassets.com" rel="dns-prefetch preconnect"/><link href="https://assets.myntassets.com" rel="dns-prefetch preconnect"/><link href="https//www.googletagmanager.com" rel="dns-prefetch preconnect"/><link href="https//www.google-analytics.com" rel="dns-prefetch preconnect"/><link href="https//connect.facebook.net" rel="dns-prefetch preconnect"/><link href="https://www.facebook.com" rel="dns-prefetch preconnect"/><link href="https://touch.myntra.com" rel="dns-prefetch preconnect"/><link href="/manifest.json" rel="manifest"/><link href="https://www.myntra.com/opensearch.xml" rel="search" title="Myntra Fashion Search" type="application/opensearchdescription+xml"/><link href="https://constant.myntassets.com/pwa/assets/img/Icon-App-60x60@3x_2021.png" rel="apple-touch-icon"/>
# ...

# %%
pclass = myntra_html.find_all("ul",{"class":"results-base"})

# %%
pclass
# Out:
# <ul class="results-base"><li class="product-base" id="24529006"><div class="product-thumbShim"></div><div class="product-ratingsContainer"><span>4.5</span><span class="myntraweb-sprite product-starIcon index-productRatingsExcellentIcon sprites-productRatingsExcellentIcon"></span><div class="product-ratingsCount"><div class="product-separator">|</div><!-- react-text: 403 -->11<!-- /react-text --></div></div><a data-refreshpage="true" href="kurtas/sangria/sangria-girls-sequinned-embellished-gotta-patti-detail-straight-kurta/24529006/buy" style="display: block;" target="_blank"><div class="product-imageSliderContainer"><div class="product-sliderContainer" style="display: block;"><div style="background: rgb(229, 241, 255);"><div style="height: 280px; width: 100%;"><picture class="img-responsive" draggable="false" style="width: 100%; height: 100%; display: block;"><source srcset="https://assets.myntassets.com/f_webp,dpr_1.5,q_60,w_210,c_limit,fl_progressive/assets/images/24529006/2023/10/
# ...

# %%
for i in pclass:
    href = i.find_all('a',href=True)
    t=(href[0]['href'])

productLink = "https://www.myntra.com/"+t

productLink
# Out:
# 'https://www.myntra.com/kurtas/modi+kurta/modi-kurta-men-chikankari-kurtas/30541233/buy'

# %%
driver.get(productLink)
proRes = driver.page_source

# %%
proRes
# Out:
# '<html lang="en"><head><title>Buy Modi Kurta Men Chikankari Kurtas  - Kurtas for Men 30541233 | Myntra</title><meta name="theme-color" content="#fffff"><link rel="dns-prefetch preconnect" href="https://constant.myntassets.com"><link rel="dns-prefetch preconnect" href="https://assets.myntassets.com"><link rel="dns-prefetch preconnect" href="https//www.googletagmanager.com"><link rel="dns-prefetch preconnect" href="https//www.google-analytics.com"><link rel="dns-prefetch preconnect" href="https//connect.facebook.net"><link rel="dns-prefetch preconnect" href="https://www.facebook.com"><link rel="dns-prefetch preconnect" href="https://touch.myntra.com"><link rel="manifest" href="/manifest.json"><link rel="search" type="application/opensearchdescription+xml" href="https://www.myntra.com/opensearch.xml" title="Myntra Fashion Search"><link rel="apple-touch-icon" href="https://constant.myntassets.com/pwa/assets/img/Icon-App-60x60@3x_2021.png">\n      <link rel="preload" as="script" href="htt
# ...

# %%
proRes_html = bs(proRes, "html.parser")
proRes_html
# Out:
# <html lang="en"><head><title>Buy Modi Kurta Men Chikankari Kurtas  - Kurtas for Men 30541233 | Myntra</title><meta content="#fffff" name="theme-color"/><link href="https://constant.myntassets.com" rel="dns-prefetch preconnect"/><link href="https://assets.myntassets.com" rel="dns-prefetch preconnect"/><link href="https//www.googletagmanager.com" rel="dns-prefetch preconnect"/><link href="https//www.google-analytics.com" rel="dns-prefetch preconnect"/><link href="https//connect.facebook.net" rel="dns-prefetch preconnect"/><link href="https://www.facebook.com" rel="dns-prefetch preconnect"/><link href="https://touch.myntra.com" rel="dns-prefetch preconnect"/><link href="/manifest.json" rel="manifest"/><link href="https://www.myntra.com/opensearch.xml" rel="search" title="Myntra Fashion Search" type="application/opensearchdescription+xml"/><link href="https://constant.myntassets.com/pwa/assets/img/Icon-App-60x60@3x_2021.png" rel="apple-touch-icon"/>
# ...

# %%
title_h = proRes_html.find_all('title')

# %%
title_h
# Out:
# [<title>Buy Modi Kurta Men Chikankari Kurtas  - Kurtas for Men 30541233 | Myntra</title>]

# %%
title = title_h[0].text

# %%
title
# Out:
# 'Buy Modi Kurta Men Chikankari Kurtas  - Kurtas for Men 30541233 | Myntra'

# %%
overallRating = proRes_html.find_all("div",{"class":"index-overallRating"})
overallRating
# Out:
# []

# %%
for i in overallRating:
    rating_value = i.find('div').text
print(rating_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 for i in overallRating:
#       2     rating_value = i.find('div').text
# ----> 3 print(rating_value)
#
# NameError: name 'rating_value' is not defined

# %%
price = proRes_html.find_all("span", {"class":"pdp-price"})
price
# Out:
# [<span class="pdp-price" tabindex="0"><strong>₹1436</strong></span>]

# %%
for i in price:
    p=i.text
print(p)
# Out:
# ₹1436

# %%
Reviews = proRes_html.find("a", {"class":"detailed-reviews-allReviews"})
Reviews

# %%
t2 = Reviews['href']
Reviews_link = "https://www.myntra.com"+t2
Reviews_link
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 t2 = Reviews['href']
#       2 Reviews_link = "https://www.myntra.com"+t2
#       3 Reviews_link
#
# TypeError: 'NoneType' object is not subscriptable

# %%
driver.get(Reviews_link)
reviews_page=driver.page_source
reviews_page
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 driver.get(Reviews_link)
#       2 reviews_page=driver.page_source
#       3 reviews_page
#
# NameError: name 'Reviews_link' is not defined

# %%
driver.quit()

# %%
reviews_html = bs(reviews_page, "html.parser")
reviews_html
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 reviews_html = bs(reviews_page, "html.parser")
#       2 reviews_html
#
# NameError: name 'reviews_page' is not defined

# %%
review = reviews_html.find_all("div", {"class": "detailed-reviews-userReviewsContainer"})
review
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 review = reviews_html.find_all("div", {"class": "detailed-reviews-userReviewsContainer"})
#       2 review
#
# NameError: name 'reviews_html' is not defined

# %%
for i in review:
    user_rating = i.find_all("div", {"class":"user-review-main user-review-showRating"})
    user_comment = i.find_all("div", {"class": "user-review-reviewTextWrapper"})
    user_name = i.find_all("div", {"class":"user-review-left"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 for i in review:
#       2     user_rating = i.find_all("div", {"class":"user-review-main user-review-showRating"})
#       3     user_comment = i.find_all("div", {"class": "user-review-reviewTextWrapper"})
#
# NameError: name 'review' is not defined

# %%
user_rating
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 user_rating
#
# NameError: name 'user_rating' is not defined

# %%
user_comment
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 user_comment
#
# NameError: name 'user_comment' is not defined

# %%
user_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 user_name
#
# NameError: name 'user_name' is not defined

# %%
for i in range(len(user_rating)):
    rating=user_rating[i].find_all("span", {"class":"user-review-starRating"}).get_text().strip()
    comment = user_comment[i].text
    name = user_name[i].find("span").text
    date = user_name[i].find_all('span')[1].text
    print(f"Data:{date}, Rating:{rating}, Name:{name}, comment:{comment}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 for i in range(len(user_rating)):
#       2     rating=user_rating[i].find_all("span", {"class":"user-review-starRating"}).get_text().strip()
#       3     comment = user_comment[i].text
#
# NameError: name 'user_rating' is not defined

# %%
# for i in range(len(user_rating)):
#     rating=user_rating[i].find_all("span", class_="user-review-starRating").get_text().strip()
#     comment = user_comment[i].text
#     name = user_name[i].find("span").text
#     date = user_name[i].find_all('span')[1].text
#     print(f"Data:{date}, Rating:{rating}, Name:{name}, comment:{comment}")

# %%
# only comment
for i in user_comment:
    com = i.text
    print(com)
